# %%
%%sql -r dataframe_13
CREATE DATABASE IF NOT EXISTS TUTORIAL_DB;

# %%
%%sql -r dataframe_1
USE DATABASE TUTORIAL_DB;

CREATE SCHEMA IF NOT EXISTS SALES_SCHEMA;

USE SCHEMA SALES_SCHEMA;

# %%
%%sql -r dataframe_2
USE WAREHOUSE COMPUTE_WH;

# %%
%%sql -r dataframe_3
CREATE WAREHOUSE IF NOT EXISTS TUTORIAL_WH
WAREHOUSE_SIZE = 'XSMALL'
AUTO_SUSPEND = 60
AUTO_RESUME = TRUE;

# %%
%%sql -r dataframe_4
USE WAREHOUSE TUTORIAL_WH;

# %%
%%sql -r dataframe_5
CREATE OR REPLACE TABLE SALES (
    SALE_ID INTEGER,
    PRODUCT VARCHAR(50),
    CUSTOMER VARCHAR(50),
    REGION VARCHAR(30),
    AMOUNT NUMBER(10,2)
);

# %%
%%sql -r dataframe_6
CREATE OR REPLACE STAGE SALES_STAGE;

# %%
%%sql -r dataframe_7
SHOW STAGES;

# %%
%%sql -r dataframe_8
INSERT INTO SALES VALUES
(1, 'Laptop', 'Rahul', 'South', 55000),
(2, 'Mobile', 'Priya', 'North', 25000),
(3, 'Tablet', 'Arjun', 'East', 18000),
(4, 'Headphones', 'Sneha', 'West', 5000),
(5, 'Keyboard', 'Kiran', 'South', 2500);

# %%
%%sql -r dataframe_9
SELECT * FROM SALES;

# %%
%%sql -r dataframe_10
INSERT INTO SALES
VALUES (6, 'Monitor', 'Anjali', 'South', 15000);

SELECT * FROM SALES;

# %%
%%sql -r dataframe_11
UPDATE SALES
SET AMOUNT = 60000
WHERE SALE_ID = 1;

SELECT * FROM SALES;

# %%
%%sql -r dataframe_12
DELETE FROM SALES
WHERE SALE_ID = 6;

SELECT * FROM SALES;
