# %%
%%sql -r dataframe_3
USE DATABASE TUTORIAL_DB;

# %%
%%sql -r dataframe_5
USE SCHEMA SALES_SCHEMA;

# %%
%%sql -r dataframe_6
CREATE OR REPLACE TABLE CUSTOMER_DATA (
    CUSTOMER_ID INTEGER,
    CUSTOMER_NAME VARCHAR(50),
    CITY VARCHAR(50),
    PURCHASE_AMOUNT NUMBER(10,2)
);

# %%
%%sql -r dataframe_7
INSERT INTO CUSTOMER_DATA VALUES
(101, 'Ravi', 'Chennai', 12000),
(102, 'Anu', 'Bangalore', 15000),
(103, 'Kiran', 'Hyderabad', 9000),
(104, 'Sneha', 'Vijayawada', 18000),
(105, 'Arjun', 'Tirupati', 11000);

# %%
%%sql -r dataframe_8
SELECT * FROM CUSTOMER_DATA;

# %%
%%sql -r dataframe_9
USE DATABASE TUTORIAL_DB;

# %%
%%sql -r dataframe_10
USE DATABASE TUTORIAL_DB;

USE SCHEMA SALES_SCHEMA;

USE SCHEMA SALES_SCHEMA;

# %%
%%sql -r dataframe_11
USE DATABASE TUTORIAL_DB;
USE SCHEMA SALES_SCHEMA;
